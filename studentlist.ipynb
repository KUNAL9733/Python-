# %%
name=input("enter your name")
age=input("enter your age")
math=input("enter ypur math score")
science=input("enter your science score")
english=input("enter your english score")
print("name:",name)
print("age:",age)
print("math score:",math)
print("science score:",science)
print("english score:",english)
# Out:
# name:
# age:
# math score:
# science score:
# english score:
